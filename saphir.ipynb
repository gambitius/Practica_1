# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ivr.txt', sep='\s+', header=None)
df1 = pd.read_csv('dataledchar.txt', sep='\s+', header=None)

# %%
df2 = pd.read_csv('data.txt', sep='\s+', header=None)

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Forward Voltage [V]')
plt.ylabel('Rd[Ω]')
plt.title('LED Small Signal Resistance vs LED Forward Voltage')
plt.grid(True)
plt.plot(df[0], df[1])
plt.legend()
plt.show
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Leer datos desde el archivo
data = np.loadtxt('rxrd.txt')

# Separar las columnas en x y y
x = data[:, 0]
y = data[:, 1]

# Grado del polinomio de ajuste (puedes ajustar este valor)
grado_polinomio = 2

# Ajuste polinómico usando NumPy
coefficients = np.polyfit(x, y, grado_polinomio)

# Crear un polinomio a partir de los coeficientes
polinomio = np.poly1d(coefficients)

# Calcular los valores de y para el polinomio ajustado
y_ajustado = polinomio(x)

# Graficar los datos y el polinomio ajustado
plt.scatter(x, y, label='Datos')
plt.plot(x, y_ajustado, color='red', label=f'Ajuste polinómico (grado {grado_polinomio})')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# Imprimir los coeficientes del polinomio
print(f'Coeficientes del polinomio: {coefficients}')
# Out:
# Coeficientes del polinomio: [  3763.29936534 -22271.58616832  33112.54760362]

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Vout [V]')
plt.ylabel('Id[A]')
plt.title('')
plt.grid(True)
plt.plot(df[0], df[2])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Leer datos desde el archivo
data = np.loadtxt('ivr.txt')

# Separar las columnas en x y y
x = data[:, 0]
y = data[:, 2]

# Grado del polinomio de ajuste
grado_polinomio = 3  # Puedes ajustar este valor

# Ajuste polinómico usando NumPy
coefficients = np.polyfit(x, y, grado_polinomio)

# Crear un polinomio a partir de los coeficientes
polinomio = np.poly1d(coefficients)

# Calcular los valores de y para el polinomio ajustado
y_ajustado = polinomio(x)

# Calcular la derivada del polinomio
derivada = np.polyder(polinomio)

# Calcular los valores de y para la derivada
y_derivada = derivada(x)
plt.figure(figsize=(10,6))
plt.grid(True)
# Graficar los datos, el polinomio ajustado y su derivada
plt.scatter(x, y, label='Datos')
plt.plot(x, y_ajustado, color='red', label=f'Ajuste polinómico (grado {grado_polinomio})')
#plt.plot(x, y_derivada, color='green', label='Derivada del ajuste')
plt.xlabel('Vout')
plt.ylabel('Id')
plt.legend()
plt.show()
print("El valor de la derivada en cada punto es:", y_derivada)
# Out:
# El valor de la derivada en cada punto es: [-0.00014079  0.01370662  0.02325115  0.03017459  0.03536024  0.03939061
#   0.04234281  0.04447449  0.0457549   0.04626995  0.04605393]

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Vin [V]')
plt.ylabel('Vout[V]')
plt.title('')
plt.grid(True)
plt.plot(df[4], df[0])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Vin [V]')
plt.ylabel('Prad[Jules per pulse]')
plt.title('')
plt.grid(True)
plt.plot(df[4], df[3])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Vout [V]')
plt.ylabel('Resistencia[Ω]')
plt.title('')
plt.grid(True)
plt.plot(df[0], df[5])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Vin [V]')
plt.ylabel('Resistencia[Ω]')
plt.title('')
plt.grid(True)
plt.plot(df[4], df[5])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np

longitud=450*10**(-9) #nm
hc=1.986*10**(-25) #ev *nm
E=hc/longitud

# Función de cálculo que deseas aplicar a cada valor
def fotones(valor):
    # Aquí realiza tu cálculo específico
    # Por ejemplo, devolver el cuadrado del valor
    return valor/(E)

# Cargar datos desde un archivo CSV
datos = np.loadtxt('ivr.txt')

# Seleccionar la columna específica
potencia = datos[:,3]

# Aplicar la función de cálculo a cada valor en la columna
resultados = [fotones(valor) for valor in potencia]

# Imprimir los resultados en orden
for i, resultado in enumerate(resultados):
    print(f"Para el valor {i}, la cantidad de fotones es: {resultado}")
# Out:
# Para el valor 0, la cantidad de fotones es: 1.2001708459214502e+16
# Para el valor 1, la cantidad de fotones es: 1.5997844410876132e+16
# Para el valor 2, la cantidad de fotones es: 2.3666900302114804e+16
# Para el valor 3, la cantidad de fotones es: 3.386872658610272e+16
# Para el valor 4, la cantidad de fotones es: 4.585571601208459e+16
# Para el valor 5, la cantidad de fotones es: 5.88002583081571e+16
# Para el valor 6, la cantidad de fotones es: 7.288567522658611e+16
# Para el valor 7, la cantidad de fotones es: 8.742860347432026e+16
# Para el valor 8, la cantidad de fotones es: 1.0281534290030213e+17
# Para el valor 9, la cantidad de fotones es: 1.1884741540785499e+17
# Para el valor 10, la cantidad de fotones es: 1.3540960422960725e+17

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Vin [V]')
plt.ylabel('Gain')
plt.title('')
plt.grid(True)
plt.plot(df1[0], df1[3])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Voltage (V)')
plt.ylabel('Gain')
plt.yscale('log')
plt.title('Relación entre Ganancia y Voltaje suministrado para el modelo R3998-02')
plt.grid(True)
plt.plot(df2[0], df2[1])
plt.legend()
plt.show
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

# Suponiendo que df2[0] contiene los voltajes y df2[1] las ganancias
# Y que quieres agregar un punto específico con error

# Datos del punto con error (ejemplo)
punto_x = 800  # Voltaje (V)
punto_y = 953721.3308  # Ganancia
error_y = 993243/2  # Error en la ganancia
py2 = 1084527.613  # Ganancia
ey2 = 1161123/2  # Error en la ganancia

px2 = 1000  # Voltaje (V)
py3 = 4203819.123  # Ganancia
ey3 = 4482581/2  # Error en la ganancia
py4 = 4537715.825  # Ganancia
ey4 = 4858381/2  # Error en la ganancia

px3 = 1200  # Voltaje (V)
py5 = 1156531.688  # Ganancia
ey5 = 1194602/2  # Error en la ganancia
py6 = 0  # Ganancia
ey6 = 0  # Error en la ganancia

# Crear el gráfico
plt.figure(figsize=(10,6))
plt.xlabel('Voltage (V)')
plt.ylabel('Gain')
plt.yscale('log')
plt.title('Relación entre la Ganancia y Voltaje suministrado con amplitud de 20mV para el modelo R3998-02')
plt.grid(True)

# Graficar los datos del DataFrame
plt.plot(df2[0], df2[2], label='Ganancia vs Voltaje')

# Agregar el punto con su error
plt.errorbar(punto_x, punto_y, yerr=error_y, fmt='o', color='red', capsize=5, label='Ganancia con error 1')
plt.errorbar(punto_x, py2, yerr=ey2, fmt='o', color='blue', capsize=5, label='Ganancia con error 2')
plt.errorbar(px2, py3, yerr=ey3, fmt='o', color='red', capsize=5)
plt.errorbar(px2, py4, yerr=ey4, fmt='o', color='blue', capsize=5)
plt.errorbar(px3, py5, yerr=ey5, fmt='o', color='red', capsize=5)
plt.errorbar(px3, py6, yerr=ey6, fmt='o', color='blue', capsize=5)

# Agregar la leyenda
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Suponiendo que df2[0] contiene los voltajes y df2[1] las ganancias
# Y que quieres agregar un punto específico con error

# Datos del punto con error (ejemplo)
px1 = 800  # Voltaje (V)
py1 = 930126.3538  # Ganancia
ey1 = 967026/2 # Error en la ganancia
py2 = 1034409.722  # Ganancia
ey2 = 1078132/2  # Error en la ganancia

px2 = 1000  # Voltaje (V)
py3 = 4053920.125  # Ganancia
ey3 = 4260330/2  # Error en la ganancia
py4 = 4426229.508   # Ganancia
ey4 = 4701236/2 # Error en la ganancia

px3 = 1200  # Voltaje (V)
py5 = 12808031.33  # Ganancia
ey5 = 13473486/2  # Error en la ganancia
py6 = 13064846.04  # Ganancia
ey6 = 13814424/2  # Error en la ganancia

# Crear el gráfico
plt.figure(figsize=(10,6))
plt.xlabel('Voltage (V)')
plt.ylabel('Gain')
plt.yscale('log')
plt.title('Relación entre la Ganancia y Voltaje suministrado con amplitud de 100mV para el modelo R3998-02')
plt.grid(True)

# Graficar los datos del DataFrame
plt.plot(df2[0], df2[2], label='Ganancia vs Voltaje')

# Agregar el punto con su error
plt.errorbar(px1, py1, yerr=ey1, fmt='o', color='red', capsize=5, label='Ganancia con error 1')
plt.errorbar(px1, py2, yerr=ey2, fmt='o', color='blue', capsize=5, label='Ganancia con error 2')
plt.errorbar(px2, py3, yerr=ey3, fmt='o', color='red', capsize=5)
plt.errorbar(px2, py4, yerr=ey4, fmt='o', color='blue', capsize=5)
plt.errorbar(px3, py5, yerr=ey5, fmt='o', color='red', capsize=5)
plt.errorbar(px3, py6, yerr=ey6, fmt='o', color='blue', capsize=5)

# Agregar la leyenda
plt.legend()

# Mostrar el gráfico
plt.show()
